# %% [markdown]
# # Tasks
#
# - We will work with Google BigQuery from Colab
# - Some part of the instructions is coming from https://colab.research.google.com/notebooks/bigquery.ipynb
# - We will use covid-19-public-data
# - In particular, we use extract the UK data
#   1. Check what kind of data are available
#   2. Find out what we can do with the data

# %% [markdown]
# ## Authentication
#
# The first step is to

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ## Load pacakges

# %%
from google.cloud import bigquery
import pandas as pd

# %% [markdown]
# ## Connect to BigQuery

# %% [markdown]
# Go to the console and check your project name and paste here

# %%
project_id = "gv918-class"

# %%
client = bigquery.Client(project=project_id)

# %% [markdown]
# ## Run queries
#
# We will use `bigquery-public-data.covid19_open_data.covid19_open_data`

# %% [markdown]
# ### Simple query
#
# Get five rows from the table
#
# - How many rows in the table?
# - How many columns exist?

# %%
df = client.query('''
SELECT * 
FROM `bigquery-public-data.covid19_open_data.covid19_open_data` 
LIMIT 10
''').to_dataframe()

# %%
df.shape
# Out:
# (10, 45)

# %%
client.query('''
SELECT COUNT(*) 
FROM `bigquery-public-data.covid19_open_data.covid19_open_data` 
''').to_dataframe()
# Out:
#        f0_
# 0  7397720

# %% [markdown]
# ### Explore the table
#
# - How many countries in the data
# - How many UK rows?
# - What's the geographical units for the UK subnational levels

# %%
client.query('''
SELECT DISTINCT(country_name) 
FROM `bigquery-public-data.covid19_open_data.covid19_open_data` 
''').to_dataframe()
# Out:
#                  country_name
# 0    United States of America
# 1                        Peru
# 2                      Mexico
# 3            French Polynesia
# 4            Papua New Guinea
# ..                        ...
# 243                     China
# 244                   Germany
# 245                  Djibouti
# 246                   Denmark
# 247                  Dominica
#
# [248 rows x 1 columns]

# %%
client.query('''
SELECT COUNT(*) 
FROM `bigquery-public-data.covid19_open_data.covid19_open_data` 
WHERE country_code = 'GB'
''').to_dataframe()
# Out:
#      f0_
# 0  67768

# %%
client.query('''
SELECT distinct(subregion2_name) 
FROM `bigquery-public-data.covid19_open_data.covid19_open_data` 
WHERE country_code = 'GB'
''').to_dataframe()
# Out:
#           subregion2_name
# 0                    None
# 1              Hartlepool
# 2           Middlesbrough
# 3    Redcar and Cleveland
# 4        Stockton-on-Tees
# ..                    ...
# 178             Hywel Dda
# 179         Aneurin Bevan
# 180      Cardiff and Vale
# 181               Cwm Taf
# 182           Swansea Bay
#
# [183 rows x 1 columns]

# %%
client.query('''
SELECT subregion2_code, subregion2_name, COUNT(subregion2_name) 
FROM `bigquery-public-data.covid19_open_data.covid19_open_data` 
WHERE country_code = 'GB'
GROUP BY subregion2_name,  subregion2_code
''').to_dataframe()
# Out:
#     subregion2_code       subregion2_name  f0_
# 0              None                  None    0
# 1         E06000001            Hartlepool  344
# 2         E06000002         Middlesbrough  344
# 3         E06000003  Redcar and Cleveland  344
# 4         E06000004      Stockton-on-Tees  344
# ..              ...                   ...  ...
# 178       W11000025             Hywel Dda  344
# 179       W11000028         Aneurin Bevan  344
# 180       W11000029      Cardiff and Vale  344
# 181       W11000030               Cwm Taf  344
# 182       W11000031           Swansea Bay  344
#
# [183 rows x 3 columns]

# %% [markdown]
# - What's the latest date in the UK?

# %%
client.query('''
SELECT MIN(date)
FROM `bigquery-public-data.covid19_open_data.covid19_open_data` 
WHERE country_code = 'GB'
''').to_dataframe()
# Out:
#           f0_
# 0  2020-01-01

# %% [markdown]
# - On 1 December 2020, at subregion2 level
#   - Which sub region had the highest number of qumulative cases

# %%
client.query('''
SELECT *
FROM `bigquery-public-data.covid19_open_data.covid19_open_data` 
WHERE country_code = 'GB' AND date = '2020-12-01' AND subregion2_code != 'None'
ORDER BY cumulative_confirmed DESC
''').to_dataframe()
# Out:
#            date      location_key  ... rainfall_mm snowfall_mm
# 0    2020-12-01  GB_ENG_E10000017  ...    0.812800        None
# 1    2020-12-01  GB_ENG_E08000025  ...    0.254000        None
# 2    2020-12-01  GB_ENG_E08000035  ...    0.203200        None
# 3    2020-12-01  GB_SCT_S08000031  ...         NaN        None
# 4    2020-12-01  GB_ENG_E10000016  ...    0.203200        None
# ..          ...               ...  ...         ...         ...
# 177  2020-12-01  GB_ENG_E06000017  ...    1.241778        None
# 178  2020-12-01  GB_SCT_S08000028  ...         NaN        None
# 179  2020-12-01  GB_SCT_S08000026  ...         NaN        None
# 180  2020-12-01  GB_SCT_S08000025  ...         NaN        None
# 181  2020-12-01  GB_ENG_E09000001  ...    0.076200        None
#
# [182 rows x 45 columns]

# %% [markdown]
# - Mobility check on 1 Dec
#   - How is the modiblity data look like?
#     - `mobility_retail_and_recreation`
#     - `mobility_parks`
#     - `mobility_workplaces`

# %%
client.query('''
SELECT *
FROM `bigquery-public-data.covid19_open_data.covid19_open_data` 
WHERE country_code = 'GB' AND date = '2020-12-01' AND subregion2_code != 'None'
ORDER BY cumulative_confirmed DESC
''').to_dataframe().describe()
# Out:
#        aggregation_level  ...  rainfall_mm
# count              182.0  ...   159.000000
# mean                 2.0  ...     0.603932
# std                  0.0  ...     0.533091
# min                  2.0  ...     0.025400
# 25%                  2.0  ...     0.093134
# 50%                  2.0  ...     0.533400
# 75%                  2.0  ...     0.914400
# max                  2.0  ...     2.257778
#
# [8 rows x 16 columns]

# %% [markdown]
# ## Work with the Essex data
#
# We can get the essex county data. Using it:
#
# - Plot the case figure growth by date
# - Plot mobility changes by date
#
# Anything interesting?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("whitegrid")

# %%
df_essex = client.query('''
SELECT *
FROM `bigquery-public-data.covid19_open_data.covid19_open_data` 
WHERE country_code = 'GB' AND subregion2_name = 'Essex'
ORDER BY cumulative_confirmed DESC
''').to_dataframe()

df_essex.head()
# Out:
#          date      location_key  ... rainfall_mm snowfall_mm
# 0  2020-12-06  GB_ENG_E10000012  ...         NaN         NaN
# 1  2020-12-05  GB_ENG_E10000012  ...         NaN         NaN
# 2  2020-12-04  GB_ENG_E10000012  ...         NaN         NaN
# 3  2020-12-03  GB_ENG_E10000012  ...      3.2004         NaN
# 4  2020-12-02  GB_ENG_E10000012  ...      0.1270         NaN
#
# [5 rows x 45 columns]

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x = 'date', y = 'cumulative_confirmed', data = df_essex)

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x = 'date', y = 'new_confirmed', data = df_essex)

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x = 'date', y = 'mobility_retail_and_recreation', data = df_essex)

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x = 'date', y = 'mobility_parks', data = df_essex)
